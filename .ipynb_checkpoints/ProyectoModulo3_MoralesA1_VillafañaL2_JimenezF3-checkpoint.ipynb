# %% [markdown]
# # Apocalipsis Zombi

# %% [markdown]
# Sístema de apocalípsis zombi (Obtenido de Munz et al. 2009) modelado con el siguiente sistema de ecuaciones de primer orden:
#
# $$
# \begin{eqnarray}
# \frac{dS}{dt} = P - BSZ - dS \\
# \frac{dZ}{dt} = BSZ + GR - ASZ \\
# \frac{dR}{dt} = dS + ASZ - GR
# \end{eqnarray}
# $$
#
# Donde:
#
#     S: Número de víctimas susceptibles
#     Z: Número de Zombis
#     R: Número de personas asesinadas
#     P: índice de nacimientos
#     d: Probabilidad de muerte natural
#     B: Probabilidad de que la "enfermedad zombi" sea transmitida en una persona viva
#     G: Probabilidad de que un muerto se convierta en zombi
#     A: Probabilidad de que un zombi sea destruido

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint

# %%
P = 0      
d = 0.0001  
B = 0.0095  
G = 0.0001  
A = 0.0001  

def f(y, t):
     Si = y[0]
     Zi = y[1]
     Ri = y[2]
     f0 = P - B*Si*Zi - d*Si
     f1 = B*Si*Zi + G*Ri - A*Si*Zi
     f2 = d*Si + A*Si*Zi - G*Ri
     return [f0, f1, f2]

# %%
#1
S0 = 500.              
Z0 = 0                 
R0 = 0                 
y0 = [S0, Z0, R0]     
t  = np.linspace(0, 8., 1000)         

soln = odeint(f, y0, t)
S = soln[:, 0]
Z = soln[:, 1]
R = soln[:, 2]

#Grafica
plt.figure(figsize=(8,6))
plt.plot(t, S, label='Vivos')
plt.plot(t, Z, label='Zombis', color='r')
plt.xlabel('Dias desde inicio')
plt.ylabel('Población')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
#2
R0 = 0.05*S0   
y0 = [S0, Z0, R0]


soln = odeint(f, y0, t)
S = soln[:, 0]
Z = soln[:, 1]
R = soln[:, 2]

#Grafica
plt.figure(figsize=(8,6))
plt.plot(t, S, label='Vivos')
plt.plot(t, Z, label='Zombis', color='r')
plt.xlabel('Dias desde inicio')
plt.ylabel('Población')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
#3
R0 = 0.01*S0   
P  = 10        
y0 = [S0, Z0, R0]

soln = odeint(f, y0, t)
S = soln[:, 0]
Z = soln[:, 1]
R = soln[:, 2]

#Grafica
plt.figure(figsize=(8,6))
plt.plot(t, S, label='Vivos')
plt.plot(t, Z, label='Zombis', color='r')
plt.xlabel('Dias desde inicio')
plt.ylabel('Población')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()
